# %% [markdown]
# # หลักสูตร The Data Master
# ## เอกสารตัวอย่างประกอบ Week 1: Python Fundamental
#
# จัดทำโดย  ดร.อิทธิพันธ์ เมธเศรษฐ

# %% [markdown]
# ## function
# *   create new function
# *   function input
# *   function output
# *   recursive function
#
# function structure
#
#
# ```python
# def function_name(argument1, argument2,...,):
#     """
#     Description of function
#     """
#
#     # Function statements
#     return(return_value)
# ```
#
#
# **Function Name:**
# The function name is how you use it later on in the code. *use a well-described function name*.
#
# **Arguments:**
# These act as variables within your function that take on the values that you pass in when you run.
#
#
# **Function Statements:**
# These are what the function will do everytime you call it.
#
# **Return Value:**
# For returning any calculations you have done within a function, you will need to use the `return` statement. You can only return one value from a function. Moreover, you can return multiple values as a tuple.

# %%
### example 3-01 ###
def my_summation(a,b):
  return a+b

x = 10
y = 5

sum = my_summation(x)
print("x ",x)
print("y ",y)
print("sum x+y ", sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-cdd09c3b0e6a> in <module>
#       6 y = 5
#       7
# ----> 8 sum = my_summation(x)
#       9 print("x ",x)
#      10 print("y ",y)
#
# TypeError: my_summation() missing 1 required positional argument: 'b'

# %% [markdown]
# ### Function Arguments

# %%
### example 3-04 ###
## default argument
def my_summation2(a,b=1):
  return a+b

x = 10
y = 5
sum = my_summation2(x)
print("x ",x)

print("sum x+_ ", sum)


sum = my_summation2(x,y)
print("x ",x)
print("y ",y)
print("sum x+y ", sum)
# Out:
# x  10
# sum x+_  11
# x  10
# y  5
# sum x+y  15

# %% [markdown]
# ### Keyword Arguments
# using keyword for input arguments

# %%
### example 3-05 ###
## keyword argument
def my_subtract(a,b=1):
  return a-b

x = 10
y = 5
sub = my_subtract(x, y)
print("x ",x)
print("y ",y)
print("sub x-y ", sub)


sub = my_subtract(b=x, a=y)
print("x ",x)
print("y ",y)
print("keyword sub x-y ", sub)
# Out:
# x  10
# y  5
# sub x-y  5
# x  10
# y  5
# keyword sub x-y  -5

# %% [markdown]
# ### Recursive Function

# %%
### example 3-06 ###
def factorial(x):
    """This is a recursive function
    to find the factorial of an integer"""

    if x == 1:
        return 1
    else:
        print(" *x ", x)
        return (x * factorial(x-1))


num = 3
print("The factorial of", num, "is", factorial(num))
# Out:
#  *x  3
#  *x  2
# The factorial of 3 is 6
