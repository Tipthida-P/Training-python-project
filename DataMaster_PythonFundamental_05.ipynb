# %% [markdown]
# # หลักสูตร The Data Master
# ## เอกสารตัวอย่างประกอบ Week 1: Python Fundamental
#
# จัดทำโดย  ดร.อิทธิพันธ์ เมธเศรษฐ

# %%
# import random
import random

# %% [markdown]
# ### Random answer in list

# %%
# prints a random value from the list
list1 = [10, 28, 32, 49, 54, "peter"]
print(random.choice(list1))
# Out:
# peter

# %% [markdown]
# ## Random integer value

# %%
for i in range(20):
   print(random.randint(0,100))
# Out:
# 79
# 1
# 6
# 95
# 87
# 60
# 17
# 80
# 83
# 83
# 76
# 69
# 14
# 68
# 12
# 20
# 67
# 89
# 8
# 51

# %% [markdown]
# ## Random floating point value

# %%
for i in range(10):
   num = 100*random.random()
   print(num)
# Out:
# 45.97685070749108
# 87.98606987966039
# 57.8367115375696
# 72.09665158623807
# 35.19710603743752
# 52.31310811099426
# 14.86719916842285
# 35.06868098527828
# 12.94941574346925
# 79.0310522279003

# %% [markdown]
# ## Random shuffle value in a list

# %%
# random shuffle
x = [10, 20, 30, 40, 50, 60]
random.shuffle(x)
print(x)
# [60, 10, 30, 20, 50, 40]
# Out:
# [60, 20, 30, 40, 10, 50]

# %% [markdown]
# ### Try it yourself

# %% [markdown]
# ### Q.5-1 สุ่มเลขลูกเต๋า (1-6)

# %%
for i in range(10):
   print(random.randint(1,6))
# Out:
# 5
# 4
# 3
# 3
# 1
# 3
# 3
# 5
# 3
# 1

# %% [markdown]
# Q.5-2: สุ่ม เลขคู่ระหว่าง 0-20

# %%
#method [0,10] *2
#for i in range(5):
#   number = random.randint(0,10)
#   print(2*number)

#method %2==0
for i in range(5):
  number = random.randint(0,10)
  if number%2==0:
    print(number)
# Out:
# 2
# 4
